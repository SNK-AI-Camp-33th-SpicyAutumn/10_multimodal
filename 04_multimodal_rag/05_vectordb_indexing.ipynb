# %% [markdown]
# # 여러 영상의 프레임 설명을 OpenAI embedding으로 검색하기
#
# 이 노트북은 04가 영상별 CSV로 저장한 프레임 설명을 하나로 모아 Vector DB에 저장하고, 자연어 질문과 가까운 장면을 찾는 실습이다. 하나의 영상만 검색하는 예제가 아니라 서로 다른 아홉 영상의 장면을 같은 의미 공간에서 비교한다.

# %% [markdown]
# ## 전체 처리 흐름
#
# 한 프레임의 상세 설명은 300자를 넘을 수 있어 여러 chunk로 나뉜다. 모든 chunk에는 같은 `frame_id`와 영상·이미지 metadata를 복사한다. 검색할 때는 chunk를 넉넉히 가져온 뒤 `frame_id`가 같은 결과를 하나만 남겨 서로 다른 실제 장면을 비교한다.
#
# ```mermaid
# flowchart TD
#     A["video_manifest.jsonl<br/>9개 video_id"] --> B["영상별 comments CSV 선택"]
#     B --> C["54개 프레임 설명 병합"]
#     C --> D["300자 chunk<br/>50자 overlap"]
#     D --> E["OpenAI caption embedding"]
#     E --> F["local Chroma<br/>cosine collection"]
#     Q["자연어 질문"] --> G["같은 OpenAI model로<br/>query embedding"]
#     F --> H["chunk 후보를 넉넉히 검색"]
#     G --> H
#     H --> I["frame_id 중복 제거"]
#     I --> J["top-k 설명·점수·실제 frame"]
# ```

# %% [markdown]
# ## 실행 환경과 API 설정
#
# 아래 패키지는 OpenAI embedding, local Chroma와 text chunking에 사용한다. 실제 API key는 `.env`에 두고 노트북 source나 출력에는 기록하지 않는다.
#
# ```bash
# pip install chromadb==1.5.9 langchain-openai==1.5.2 python-dotenv==1.2.3 pandas pillow matplotlib
# ```
#
# OpenAI embedding 호출은 사용량에 따른 비용이 발생한다. 이 교안에는 `text-embedding-3-small`로 54개 설명을 실제 색인하고 세 질문을 검색한 출력이 저장되어 있다.

# %%
# %pip install chromadb==1.5.9 langchain-openai==1.5.2 python-dotenv==1.2.3 pandas pillow matplotlib
# Out:
# Requirement already satisfied: chromadb==1.5.9 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.5.9)
# Collecting langchain-openai==1.5.2
#   Using cached langchain_openai-1.5.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dotenv==1.2.3 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.2.3)
# Requirement already satisfied: pandas in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (3.0.5)
# Requirement already satisfied: pillow in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (12.2.0)
# Requirement already satisfied: matplotlib in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (3.11.1)
# Requirement already satisfied: build>=1.0.3 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (2.15.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.9) (0.52.1)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (2.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (4.16.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.28.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (4.70.0)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (0.27.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from chromadb==1.5.9) (4.26.0)
# Requirement already satisfied: certifi>=2024.6.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai==1.5.2) (2026.7.22)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.6 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai==1.5.2) (1.6.0)
# Collecting openai<4.0.0,>=2.45.0 (from langchain-openai==1.5.2)
#   Downloading openai-3.5.0-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai==1.5.2) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.27.0->chromadb==1.5.9) (4.14.2)
# Requirement already satisfied: httpcore==1.* in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.27.0->chromadb==1.5.9) (1.0.9)
# Requirement already satisfied: idna in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.27.0->chromadb==1.5.9) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==1.5.9) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (0.25.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai==1.5.2) (2.10.0)
# Requirement already satisfied: jiter<1,>=0.16.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai==1.5.2) (0.16.0)
# Requirement already satisfied: httpcore2==2.10.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai==1.5.2) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai==1.5.2) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.0->chromadb==1.5.9) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.0->chromadb==1.5.9) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.0->chromadb==1.5.9) (0.4.2)
# Requirement already satisfied: regex in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai==1.5.2) (2026.7.19)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: pyproject_hooks in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from build>=1.0.3->chromadb==1.5.9) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from build>=1.0.3->chromadb==1.5.9) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb==1.5.9) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb==1.5.9) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb==1.5.9) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb==1.5.9) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb==1.5.9) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb==1.5.9) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb==1.5.9) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb==1.5.9) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb==1.5.9) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb==1.5.9) (3.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb==1.5.9) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb==1.5.9) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb==1.5.9) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb==1.5.9) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb==1.5.9) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb==1.5.9) (1.24.5)
# Requirement already satisfied: flatbuffers in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from onnxruntime>=1.14.1->chromadb==1.5.9) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from onnxruntime>=1.14.1->chromadb==1.5.9) (7.35.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.9) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.9) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.9) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb==1.5.9) (0.65b0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.6->langchain-openai==1.5.2) (3.4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from rich>=10.11.0->chromadb==1.5.9) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from rich>=10.11.0->chromadb==1.5.9) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==1.5.9) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tokenizers>=0.13.2->chromadb==1.5.9) (0.36.2)
# Requirement already satisfied: filelock in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.9) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.9) (2025.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from typer>=0.9.0->chromadb==1.5.9) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from typer>=0.9.0->chromadb==1.5.9) (0.0.5)
# Requirement already satisfied: click>=7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==1.5.9) (8.4.2)
# Requirement already satisfied: httptools>=0.8.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.9) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.9) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==1.5.9) (3.3.1)
# Using cached langchain_openai-1.5.2-py3-none-any.whl (124 kB)
# Downloading openai-3.5.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 30.5 MB/s  0:00:00
# Installing collected packages: openai, langchain-openai
#
#   Attempting uninstall: openai
#
#     Found existing installation: openai 2.15.0
#
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#     Uninstalling openai-2.15.0:
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#       Successfully uninstalled openai-2.15.0
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#   Attempting uninstall: langchain-openai
#    ---------------------------------------- 0/2 [openai]
#     Found existing installation: langchain-openai 1.6.0
#    ---------------------------------------- 0/2 [openai]
#     Uninstalling langchain-openai-1.6.0:
#    ---------------------------------------- 0/2 [openai]
#       Successfully uninstalled langchain-openai-1.6.0
#    ---------------------------------------- 0/2 [openai]
#    -------------------- ------------------- 1/2 [langchain-openai]
#    -------------------- ------------------- 1/2 [langchain-openai]
#    -------------------- ------------------- 1/2 [langchain-openai]
#    -------------------- ------------------- 1/2 [langchain-openai]
#    -------------------- ------------------- 1/2 [langchain-openai]
#    -------------------- ------------------- 1/2 [langchain-openai]
#    ---------------------------------------- 2/2 [langchain-openai]
#
# Successfully installed langchain-openai-1.5.2 openai-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Corpus 경로와 영상 allowlist 준비하기
#
# **Corpus**는 한 번에 검색할 문서 집합이다. `video_manifest.jsonl`의 `video_id`를 allowlist로 사용하면 comments 폴더에 과거 CSV가 남아 있어도 이번 아홉 영상만 indexing할 수 있다. `find_dotenv()`는 현재 작업 폴더부터 상위 폴더를 탐색해 `.env`를 process 환경변수로 불러온다.

# %%
import json
import os
from pathlib import Path

from dotenv import find_dotenv, load_dotenv

ENV_PATH = find_dotenv(usecwd=True)
load_dotenv(ENV_PATH)

CORPUS_ID = 'mixkit_9_v1'
ARTIFACT_ROOT = Path('artifacts/multimodal_rag') / CORPUS_ID
COMMENT_DIR = ARTIFACT_ROOT / 'comments'
VIDEO_MANIFEST_PATH = ARTIFACT_ROOT / 'video_manifest.jsonl'
FRAME_MANIFEST_PATH = ARTIFACT_ROOT / 'frame_manifest.jsonl'
CHROMA_DIR = ARTIFACT_ROOT / 'chroma'
COLLECTION_NAME = 'video_frame_descriptions_openai_mixkit9_v1'
EMBEDDING_MODEL_ID = os.getenv('OPENAI_EMBEDDING_MODEL') or 'text-embedding-3-small'

# video_manifest.jsonl을 읽어와서
# 한 줄씩 dict로 변환 후 video_records에 누적
video_records = [
    json.loads(line)
    for line in VIDEO_MANIFEST_PATH.read_text(encoding='utf-8').splitlines()
    if line.strip()
]
# 준비된 영상 id 목록
allowed_video_ids = {str(record['video_id']) for record in video_records}

if len(allowed_video_ids) != 9:
    raise ValueError(f'video manifest에는 9개의 고유 video_id가 필요하다: {len(allowed_video_ids)}개')

print(f'corpus_id={CORPUS_ID}')
print(f'videos={len(allowed_video_ids)}')
print(f'embedding_model={EMBEDDING_MODEL_ID}')
# Out:
# corpus_id=mixkit_9_v1
# videos=9
# embedding_model=text-embedding-3-small

# %% [markdown]
# ## 영상별 프레임 설명 CSV 병합하기
#
# 04는 영상 하나당 `{video_id}_frames.csv`를 만든다. 각 CSV의 한 행은 프레임 하나이며, 설명뿐 아니라 검색 결과를 원본 장면으로 되돌릴 경로와 시각 정보를 포함한다. 파일별 shape를 먼저 출력한 뒤 총 54행을 하나의 DataFrame으로 합친다.

# %%
import pandas as pd

comment_frames = []
for video_id in sorted(allowed_video_ids):

    csv_path = COMMENT_DIR / f'{video_id}_frames.csv'
    frame_df = pd.read_csv(csv_path)
    print(f'{csv_path.name}: shape={frame_df.shape}')
    comment_frames.append(frame_df)

# 9개의 csv -> df을 1개의 df 변경 (인덱스 번호 재설정)
all_comments_df = pd.concat(comment_frames, ignore_index=True)
if len(all_comments_df) != 54:
    raise ValueError(f'프레임 설명은 54행이어야 한다: {len(all_comments_df)}행')

print(f'merged_shape={all_comments_df.shape}')
display(all_comments_df[['video_id', 'frame_no', 'timestamp_sec', 'description']].head(3))
# Out:
# basketball_frames.csv: shape=(6, 11)
# cooking_frames.csv: shape=(6, 11)
# cycling_frames.csv: shape=(6, 11)
# dog_ball_frames.csv: shape=(6, 11)
# running_frames.csv: shape=(6, 11)
# soccer_frames.csv: shape=(6, 11)
# surfing_frames.csv: shape=(6, 11)
# swimming_frames.csv: shape=(6, 11)
# traffic_frames.csv: shape=(6, 11)
# merged_shape=(54, 11)
#      video_id  frame_no  timestamp_sec  \
# 0  basketball        27       1.125000
# 1  basketball       125       5.208333
# 2  basketball       223       9.291667
#
#                                          description
# 0  검은 민소매 상의와 반바지를 입은 남성이 농구 코트 위에 서 있다.  \n남성은 코...
# 1  한 남성이 농구 코트 위를 걷고 있으며, 어두운 민소매 상의와 반바지, 파란 양말과...
# 2  한 남성이 검은색 민소매 상의와 반바지, 운동화를 착용하고 있다.  \n그는 야외 ...

# %% [markdown]
# ## 긴 설명을 겹치는 chunk로 나누기
#
# **Chunking**은 긴 문서를 검색하기 좋은 작은 구간으로 나누는 과정이다. `chunk_size=300`은 chunk의 최대 문자 수이고 `chunk_overlap=50`은 경계 앞뒤 문맥을 이어 주는 중복 문자 수이다. 한 프레임에서 여러 chunk가 생겨도 모든 chunk에 같은 `frame_id`와 경로 정보를 남긴다.
#
# `chunk_id`는 `frame_id`와 chunk 순서를 SHA-256으로 변환해 만든다. 같은 입력을 다시 처리하면 같은 ID가 만들어져 실행마다 임의 ID가 늘어나지 않는다.

# %%
import hashlib

CHUNK_SIZE = 300
CHUNK_OVERLAP = 50

def split_with_overlap(text: str, chunk_size: int = CHUNK_SIZE, overlap: int = CHUNK_OVERLAP):

    step = chunk_size - overlap
    return [text[start:start + chunk_size] for start in range(0, len(text), step)]

chunk_records = []

for row in all_comments_df.to_dict(orient='records'):
    description_chunks = split_with_overlap(str(row['description']))
    chunk_count = len(description_chunks)
    for chunk_index, chunk_text in enumerate(description_chunks):

        raw_chunk_id = f"{row['frame_id']}:{chunk_index}".encode('utf-8')
        chunk_id = hashlib.sha256(raw_chunk_id).hexdigest()[:24]
        chunk_records.append({
            'chunk_id': chunk_id,
            'text': chunk_text,
            'metadata': {
                'frame_id': str(row['frame_id']),
                'video_id': str(row['video_id']),
                'video_filename': str(row['video_filename']),
                'video_path': str(row['video_path']),
                'frame_path': str(row['frame_path']),
                'frame_no': int(row['frame_no']),
                'timestamp_sec': float(row['timestamp_sec']),
                'caption_model': str(row['caption_model']),
                'prompt_version': str(row['prompt_version']),
                'chunk_index': chunk_index,
                'chunk_count': chunk_count,
            },
        })

print(f'frames={len(all_comments_df)}')
print(f'chunks={len(chunk_records)}')
print(chunk_records[0])
# Out:
# frames=54
# chunks=54
# {'chunk_id': '08b9e29a1f154ffb2dcc3fa5', 'text': '검은 민소매 상의와 반바지를 입은 남성이 농구 코트 위에 서 있다.  \n남성은 코트 위를 걸으며 한쪽 다리를 앞으로 내딛고 있다.  \n코트 뒤로는 계단, 콘크리트 벽, 나무와 여러 식물이 있는 야외 공간이 보인다.  \n코트 바닥에는 흰색 곡선과 선이 표시되어 있고, 남성은 파란 양말과 운동화를 착용하고 있다.', 'metadata': {'frame_id': 'db13baa34b521662', 'video_id': 'basketball', 'video_filename': 'basketball.mp4', 'video_path': 'artifacts/multimodal_rag/mixkit_9_v1/videos/basketball.mp4', 'frame_path': 'artifacts/multimodal_rag/mixkit_9_v1/frames/basketball/basketball_frame0000027.jpg', 'frame_no': 27, 'timestamp_sec': 1.125, 'caption_model': 'gpt-5.6-luna', 'prompt_version': 'scene_v1', 'chunk_index': 0, 'chunk_count': 1}}

# %% [markdown]
# ## OpenAI embedding 생성하기
#
# Embedding은 문장의 의미를 숫자 vector로 바꾸는 과정이다. `embed_documents()`는 모든 chunk 문자열을 같은 model에 전달하며, 반환 순서는 입력 문자열 순서와 같다. 따라서 다음 저장 단계에서도 chunk ID·text·metadata·embedding의 순서를 바꾸지 않는다.

# %%
import numpy as np
from langchain_openai import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model=EMBEDDING_MODEL_ID)

chunk_texts = [record['text'] for record in chunk_records]

chunk_embeddings = np.asarray(
    embedding_model.embed_documents(chunk_texts),
    dtype=np.float32,
)

print(f'embedding_shape={chunk_embeddings.shape}')
print(f'chunks={len(chunk_records)}')
# Out:
# embedding_shape=(54, 1536)
# chunks=54

# %% [markdown]
# ## Corpus 전용 Chroma collection 만들기
#
# Chroma collection은 같은 검색 목적의 vector와 metadata를 묶는 단위이다. 이 실습은 재실행할 때 이전 `mixkit_9_v1` record가 남지 않도록 같은 이름의 collection만 다시 만든다. `hnsw:space="cosine"`은 vector 방향의 유사성을 거리로 계산한다.

# %%
import chromadb

CHROMA_DIR.mkdir(parents=True, exist_ok=True)

chroma_client = chromadb.PersistentClient(path=str(CHROMA_DIR))

existing_names = {collection.name for collection in chroma_client.list_collections()}
if COLLECTION_NAME in existing_names:
    chroma_client.delete_collection(name=COLLECTION_NAME)

frame_collection = chroma_client.create_collection(
    name=COLLECTION_NAME,
    metadata={
        'hnsw:space': 'cosine',
        'corpus_id': CORPUS_ID,
        'embedding_model': EMBEDDING_MODEL_ID,
    },
)

print(f'collection={frame_collection.name}')
print(f'initial_count={frame_collection.count()}')
# Out:
# collection=video_frame_descriptions_openai_mixkit9_v1
# initial_count=0

# %% [markdown]
# ## Chunk와 metadata를 50개씩 저장하기
#
# Upsert는 같은 ID가 있으면 갱신하고 없으면 추가한다. `BATCH_SIZE=50`은 한 요청에 전달할 record 수이며, 각 batch에서 ID·문장·metadata·embedding의 같은 위치가 하나의 record가 된다.

# %%
BATCH_SIZE = 50

for start in range(0, len(chunk_records), BATCH_SIZE):

    end = start + BATCH_SIZE
    batch_records = chunk_records[start:end]

    # upsert(update + insert)
    frame_collection.upsert(
        ids=[record['chunk_id'] for record in batch_records],
        documents=[record['text'] for record in batch_records],
        metadatas=[record['metadata'] for record in batch_records],
        embeddings=chunk_embeddings[start:end].tolist(),
    )

print(f'collection_count={frame_collection.count()}')
print(f'expected_chunks={len(chunk_records)}')
# Out:
# collection_count=54
# expected_chunks=54

# %% [markdown]
# ## 프레임 중복을 제거하는 검색 함수 만들기
#
# 한 프레임의 여러 chunk가 모두 높은 순위에 들어오면 일반적인 top-k는 같은 장면만 반복할 수 있다. 이 함수는 필요한 프레임 수보다 많은 chunk를 검색하고, 가까운 순서대로 처음 만난 `frame_id`만 남긴다. 반환 결과 하나는 서로 다른 실제 프레임 하나를 의미한다.

# %%
def search_unique_frames(
        query:str,
        top_k:int=3,
        overfetch_factor:int=5,
):

    # 사용자로부터 입력 받은 질문은 임베딩
    query_embedding = embedding_model.embed_query(query)

    # 질문에 대한 정답 문장 후보의 최대 개수 지정
    candidate_count = min(
        frame_collection.count(),
        max(top_k, top_k * overfetch_factor),
    )

    # 질문과 유사도가 높은 후보 candidate_count개 만큼 조회
    raw_result = frame_collection.query(
        query_embeddings = [query_embedding],
        n_results = candidate_count,
        include = ['documents', 'metadatas', 'distances'],
    )

    # Chroma 반환값은 질문별 중첩 list이므로 첫 질문의 네 필드를 같은 rank끼리 묶는다.
    unique_results = []
    seen_frame_ids = set()
    candidates = zip(
        raw_result['ids'][0],
        raw_result['documents'][0],
        raw_result['metadatas'][0],
        raw_result['distances'][0],
    )
    for chunk_id, text, metadata, distance in candidates:
        frame_id = metadata['frame_id']
        if frame_id in seen_frame_ids:
            continue
        seen_frame_ids.add(frame_id)
        unique_results.append({
            'chunk_id': chunk_id,
            'text': text,
            'metadata': metadata,
            'distance': float(distance),
            'similarity': 1.0 - float(distance),
        })
        if len(unique_results) == top_k:
            break
    return unique_results

# %% [markdown]
# ## 검색 결과를 표와 실제 프레임으로 표시하기
#
# 표는 검색 문장뿐 아니라 영상 ID, 시각, similarity를 함께 보여 준다. 그 아래 실제 프레임을 표시하여 의미 점수가 높다는 이유만으로 정답이라고 단정하지 않고 픽셀 근거까지 확인한다.

# %%
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from PIL import Image

def display_search_results(query: str, results: list[dict]):

    table_lines = [
        '| rank | video_id | timestamp | similarity | description chunk |',
        '|---:|---|---:|---:|---|',
    ]
    for rank, result in enumerate(results, start=1):

        metadata = result['metadata']
        safe_text = result['text'].replace('|', '&#124;').replace('\n', ' ')
        table_lines.append(
            f"| {rank} | {metadata['video_id']} | {float(metadata['timestamp_sec']):.2f}s | "
            f"{result['similarity']:.4f} | {safe_text} |"
        )
    display(Markdown(f'**질문:** {query}\n\n' + '\n'.join(table_lines)))

    figure, axes = plt.subplots(1, len(results), figsize=(5 * len(results), 4.2), squeeze=False)

    for index, result in enumerate(results):
        metadata = result['metadata']
        with Image.open(Path(metadata['frame_path'])) as image:
            axes[0, index].imshow(image.convert('RGB'))
        axes[0, index].axis('off')
        axes[0, index].set_title(
            f"rank {index + 1} | {metadata['video_id']}\n"
            f"{float(metadata['timestamp_sec']):.2f}s | sim={result['similarity']:.4f}",
            fontsize=9,
        )
    figure.tight_layout()
    plt.show()

# %% [markdown]
# ## 서로 다른 세 영상 장면 검색하기
#
# 강아지, 서핑과 교통은 서로 다른 영상의 장면을 묻는다. 각 질문에서 top-1이 기대한 영상과 실제 장면을 가리키는지 확인하면 하나의 collection이 여러 영상을 함께 검색하는지 알 수 있다.

# %%
SEARCH_EXAMPLES = [
    '강아지가 공을 물고 달리는 장면',
    '서퍼가 파도를 타는 장면',
    '도로에서 자동차가 이동하는 장면',
]

for query in SEARCH_EXAMPLES:

    results = search_unique_frames(query, top_k=3)
    display_search_results(query, results)
# Out:
# **질문:** 강아지가 공을 물고 달리는 장면
#
# | rank | video_id | timestamp | similarity | description chunk |
# |---:|---|---:|---:|---|
# | 1 | soccer | 5.33s | 0.3668 | 여러 명의 축구 선수들이 인조 잔디 구장에서 공을 두고 움직이고 있다.   앞쪽에는 검은색 상의와 반바지를 입은 선수가 달리고 있으며, 가까운 곳에는 회색 상의와 검은색 반바지를 입은 선수가 서 있다.   뒤쪽에는 골대와 파란색 상의를 입은 선수가 보이고, 구장 주변은 높은 그물과 나무로 둘러싸여 있다.   카메라는 지면 가까이에서 촬영되어 앞쪽 선수와 잔디가 크게 보인다. |
# | 2 | swimming | 7.67s | 0.3575 | 수영장 물속에 한 사람이 잠긴 채 앞쪽으로 이동하는 모습이 보인다.   장면은 야외 수영장으로, 뒤편에 넓은 지붕의 건물과 흰색 기둥, 난간이 있다.   맑고 푸른 물 표면의 반사와 물결 때문에 인물의 모습이 흐릿하게 왜곡되어 보인다. |
# | 3 | running | 28.49s | 0.3239 | 붉은 상의와 어두운색 하의를 입은 사람이 숲길을 따라 달리고 있다.   주변에는 키 큰 나무들이 늘어서 있고, 흙으로 된 오솔길과 나무 사이의 녹지가 보인다.   햇빛과 나뭇잎 그림자가 길 위에 드리워져 있으며, 인물은 화면 중앙에서 뒷모습으로 작게 보인다. |
# **질문:** 서퍼가 파도를 타는 장면
#
# | rank | video_id | timestamp | similarity | description chunk |
# |---:|---|---:|---:|---|
# | 1 | surfing | 17.14s | 0.4609 | 바다에서 한 사람이 파도를 타고 있다.   사람은 화면 왼쪽 아래쪽의 부서지는 흰 파도 가장자리에 서 있다.   넓은 바다와 흐린 하늘이 보이며, 오른쪽 뒤편에는 안개 낀 해안선과 산이 이어져 있다.   전체적으로 푸른 회색빛의 흐린 분위기와 길게 굽이치는 파도가 눈에 띈다. |
# | 2 | surfing | 4.17s | 0.4426 | 바다 위에 서퍼 한 명이 서핑보드를 타고 파도를 가르고 있다.   서퍼 뒤쪽으로 작은 인물이 보이며, 주변에는 넓은 바다와 부서지는 흰 파도가 펼쳐져 있다.   멀리 안개 낀 수평선 너머로 산과 해안선이 희미하게 보이고, 전체적으로 푸른빛과 회색빛이 감도는 장면이다. |
# | 3 | surfing | 7.42s | 0.4348 | 바다의 큰 파도 위에 서퍼 한 명이 서핑보드를 타고 이동하고 있다.   서퍼 주변으로 흰 포말이 일며 파도가 길게 부서지고 있다.   넓은 바다 뒤로 안개 낀 해안 산지가 희미하게 보이며, 화면 왼쪽 먼 곳에는 작은 인물 하나가 떠 있다. |
# **질문:** 도로에서 자동차가 이동하는 장면
#
# | rank | video_id | timestamp | similarity | description chunk |
# |---:|---|---:|---:|---|
# | 1 | traffic | 10.27s | 0.4423 | 도로에 파란색 버스와 여러 대의 승용차가 있으며, 횡단보도에는 여러 사람이 걷고 있다.   사람들은 차량이 멈춰 있는 교차로의 넓은 횡단보도를 건너고 있다.   장면은 도심 교차로로, 주변에 건물 입구와 신호등, 보도, 차량 행렬이 보인다.   버스 앞면에는 ‘ADVANCE’라는 글자가 표시되어 있고, 횡단보도와 차량이 화면을 가로지르는 구도가 두드러진다. |
# | 2 | traffic | 0.67s | 0.4038 | 교차로에 많은 보행자와 노란 택시, 승용차들이 보인다.   보행자들은 횡단보도를 건너고 있으며, 차량들은 횡단보도 앞 차로에 서 있거나 이동하고 있다.   도심의 넓은 도로와 인도, 신호등 및 건물 일부가 배경에 보인다.   여러 대의 노란 택시와 대각선으로 이어진 흰색 횡단보도가 화면에서 두드러진다. |
# | 3 | traffic | 12.67s | 0.4024 | 도로 교차로에 노란색 택시 두 대와 검은색·흰색 승용차, 흰색 밴이 보인다.   차량들은 횡단보도와 차선 위에서 서로 다른 방향으로 이동하고 있으며, 왼쪽 인도에는 많은 보행자가 모여 있다.   장소는 신호등과 횡단보도가 있는 도심의 넓은 교차로로, 주변에 건물과 가로수가 일부 보인다.   노란색 택시와 대각선으로 칠해진 넓은 횡단보도가 화면에서 두드러진다. |

# %% [markdown]
# ## 핵심 정리
#
# 05의 핵심은 여러 영상의 상세 설명을 한 collection에 저장하되 검색 결과를 다시 실제 프레임으로 연결하는 것이다. Chunk는 검색 단위이고 frame은 사용자에게 보여 줄 근거 단위이므로, 검색 후 `frame_id` 중복을 제거해야 한다.
#
# OpenAI embedding의 similarity는 정답 확률이 아니다. 질문 표현, 캡션 품질과 corpus 구성에 따라 달라지므로 표의 점수와 실제 프레임을 함께 확인한다.
